# %%
import pandas as pd
data1= pd.read_csv("data/Op tafel/Accelerometer.csv", delimiter = ";")
data2 = pd.read_csv("data/Op tafel/Barometer.csv", delimiter = ";")
data3 = pd.read_csv("data/Op tafel/Gyroscope.csv", delimiter = ";")
data4 = pd.read_csv("data/Op tafel/Linear Accelerometer.csv", delimiter = ";")
# data5 = pd.read_csv("data/Op tafel/Location.csv", delimiter = ";")
data6 = pd.read_csv("data/Op tafel/Magnetometer.csv", delimiter = ";")
data7 = pd.read_csv("data/Op tafel/Proximity.csv", delimiter = ";")
data1
# Out:
#           Time (s)     X (m/s^2)     Y (m/s^2)    Z (m/s^2)
# 0      0,001250292  -0,050145721  -0,020207977  9,873617706
# 1      0,011207292  -0,049397278  -0,000149689  9,865235138
# 2      0,021141292  -0,050744476  -0,001347198  9,876761169
# 3      0,031073292  -0,040565643  -0,012573853  9,862989807
# 4      0,041005292  -0,022004242  -0,020806732  9,870773621
# ...            ...           ...           ...          ...
# 31432  312,1857739  -0,021704865  -0,053887939   9,88723938
# 31433  312,1957069  -0,028291168  -0,069305878  9,881551208
# 31434  312,2056389  -0,040565643  -0,074544983  9,882748718
# 31435  312,2155709  -0,062420197  -0,053588562  9,871222687
# 31436  312,2255039  -0,054636383   -0,01047821  9,852361908
#
# [31437 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(data1['Time (s)'], data1['X (m/s^2)'])
# plt.plot(data1['Y (m/s^2)'])
# plt.plot(data1['X (m/s^2)'])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Error in callback <function flush_figures at 0x000001D96454F040> (for post_execute):
# Traceback (most recent call last):
#   File "C:\Users\maxin\anaconda3\lib\site-packages\IPython\core\events.py", line 89, in trigger
#     func(*args, **kwargs)
#   File "C:\Users\maxin\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py", line 121, in flush_figures
#     return show(True)
#   File "C:\Users\maxin\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py", line 41, in show
#     display(
#   File "C:\Users\maxin\anaconda3\lib\site-packages\IPython\core\display.py", line 313, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "C:\Users\maxin\anaconda3\lib\site-packages\IPython\core\formatters.py", line 180, in format
#     data = formatter(obj)
# ...

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement util
# ERROR: No matching distribution found for util
